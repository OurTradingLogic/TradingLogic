# %% [markdown]
# First connect to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Run Python Script

# %%
# !pip install gspread==5.6.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gspread
#     Found existing installation: gspread 3.4.2
#     Uninstalling gspread-3.4.2:
#       Successfully uninstalled gspread-3.4.2
# ...

# %%
# !python3 "/content/drive/MyDrive/GitHub/TradingLogic/Test2.py"
# Out:
# Welcome

# %% [markdown]
# Please Refer gspread document for more google sheet methods:
# Here, I am sharing that. Please refer
# https://docs.gspread.org/en/latest/user-guide.html

# %% [markdown]
# Thank you all... see again
